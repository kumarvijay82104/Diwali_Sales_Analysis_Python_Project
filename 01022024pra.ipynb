# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Diwali Sales Data.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
df.info()

# %%
#check for the null value
df.isnull().sum()

# %%
# drop null values
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0

# %%
df['Amount'].dtype
# Out:
# dtype('float64')

# %%
#changing float column in integer 
df['Amount'] =df['Amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df.describe(include='object')
# Out:
#        Cust_name Product_ID Gender Age Group          State     Zone  \
# count      11239      11239  11239     11239          11239    11239
# unique      1250       2350      2         7             16        5
# top     Vishakha  P00265242      F     26-35  Uttar Pradesh  Central
# freq          42         53   7832      4541           1944     4289
#
#        Occupation    Product_Category
# count       11239               11239
# unique         15                  18
# top     IT Sector  Clothing & Apparel
# freq         1583                2655

# %%
for i in df.describe(include='object') :
    print(i)
    print(df[i])
    print('-'*50)
# Out:
# Cust_name
# 0          Sanskriti
# 1             Kartik
# 2              Bindu
# 3             Sudevi
# 4               Joni
#             ...
# 11246        Manning
# 11247    Reichenbach
# 11248          Oshin
# 11249         Noonan
# 11250        Brumley
# Name: Cust_name, Length: 11239, dtype: object
# --------------------------------------------------
# Product_ID
# 0        P00125942
# 1        P00110942
# 2        P00118542
# 3        P00237842
# 4        P00057942
#            ...
# 11246    P00296942
# 11247    P00171342
# 11248    P00201342
# 11249    P00059442
# 11250    P00281742
# Name: Product_ID, Length: 11239, dtype: object
# --------------------------------------------------
# Gender
# 0        F
# 1        F
# 2        F
# 3        M
# 4        M
#         ..
# 11246    M
# 11247    M
# 11248    F
# 11249    M
# 11250    F
# Name: Gender, Length: 11239, dtype: object
# --------------------------------------------------
# Age Group
# 0        26-35
# 1        26-35
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#Rename column 
df.rename(columns= {'Marital_Status':'shadhi'},inplace=True)

# %%
nummm  = df[['Age','Orders','Amount']]

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
df.

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'User_ID'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'shadhi'}>,
#         <Axes: title={'center': 'Orders'}>],
#        [<Axes: title={'center': 'Amount'}>, <Axes: >]], dtype=object)

# %%
df["Age"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["Orders"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["Amount"].plot(kind="box")
# Out:
# <Axes: >

# %%
df.sort_values('Amount',ascending=False).tail(10)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  shadhi  \
# 11241  1003032     Matthias  P00058042      F     26-35   33       0
# 11242  1004344   Hildebrand  P00185442      F     26-35   27       1
# 11243  1005446      Sheetal  P00297742      M     51-55   53       0
# 11244  1005446      Sheetal  P00297742      M     51-55   53       0
# 11245  1004140    Bertelson  P00057442      F     26-35   31       1
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount
# 11241           Delhi   Central  Hospitality           Office       3     384
# ...

# %%
df["Amount"].min(), df["Orders"].min()
# Out:
# (188, 1)

# %%
# Assuming 'Orders' is the column you want to filter based on the value 1
df[df['Orders'] == 1]
# Out:
#        User_ID  Cust_name Product_ID Gender Age Group  Age  shadhi  \
# 0      1002903  Sanskriti  P00125942      F     26-35   28       0
# 5      1000588       Joni  P00057942      M     26-35   28       1
# 10     1003829   Harshita  P00200842      M     26-35   34       0
# 17     1001193       Mick  P00004842      F     26-35   29       0
# 18     1001883    Praneet  P00029842      M     51-55   54       1
# ...        ...        ...        ...    ...       ...  ...     ...
# 11233  1002106       Luke  P00164342      M     18-25   19       0
# 11238  1002718   Abhishek  P00003442      M     26-35   28       0
# 11239  1000802     Marley  P00245642      F     26-35   33       0
# 11240  1001425     Sudevi  P00044742      F      0-17   12       0
# 11243  1005446    Sheetal  P00297742      M     51-55   53       0
#
#                   State      Zone       Occupation Product_Category  Orders  \
# 0           Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.shape
# Out:
# (11239, 13)

# %%
round((2808/11239)*100)
# Out:
# 25

# %% [markdown]
# Through of the above calculation we can clearly seen that our 25% user juts order only one iteam

# %% [markdown]
# # Exploratory Data Analysis

# %%
# plotting a bar chart for Gender and it's count
#ax = sns.countplot(x='Gender', data = df)
#for i in ax.containers:
#    ax.bar_label(bars)
ax = sns.countplot(x='Gender',data = df)
for i in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount
#sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending = False)
#sns.barplot(x = 'Gender',y= 'Amount',data =sales_gen)

sales_genn = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending = False)
sns.barplot(x='Gender',y='Amount',data = sales_genn)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
# plotting a bar chart for gender vs total amount
#sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending = False)
#sns.barplot(x = 'Gender',y= 'Amount',data =sales_gen

# %%
ax = sns.countplot(data = df,x= 'Age Group' ,hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

ax = sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
for i in ax.containers:
    ax.bar_label(bars,label_type = 'edge')

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# ### Top 10 state wise Orders and Sales amount

# %%
# total number of orders from top 10 states
sales_state = df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending = False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x= 'State', y = 'Amount',data = sales_state )
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
# total number of orders from top 10 states
order_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by = 'Orders',ascending = False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x= 'State', y = 'Orders',data = order_state )
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# ### Marital Status

# %%
ax = sns.countplot(x='shadhi',data = df)

sns.set(rc={'figure.figsize':(7,5)})
for i in ax.containers:
    ax.bar_label(bars)

# %%
sales_state_gender_sadhi = df.groupby(['shadhi','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending = False)

sns.set(rc={'figure.figsize':(6,5)})
ax = sns.barplot(x='shadhi',y='Amount',hue='Gender',data=sales_state_gender_sadhi )

for i in ax.containers:
    ax.bar_label(bars)

# %%
sales_state_gender_sadhi = df.groupby(['shadhi','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending = False)

sns.set(rc={'figure.figsize':(6,5)})
ax = sns.barplot(x='shadhi',y='Amount',hue='Gender',data=sales_state_gender_sadhi )

# %% [markdown]
# *From above graphs we can see that most of the buyers are married (women) and they have high purchasing power*

# %% [markdown]
# ### Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')
for i in ax.containers:
    ax.bar_label(bars)

# %%
sns.set(rc={'figure.figsize':(20,5)})
sales_state_Occupation = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending= False)
ax = sns.barplot(x= 'Occupation', y= 'Amount', data = sales_state_Occupation)
for i in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# ### Product Category

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(x= 'Product_Category',data = df)
for i in ax.containers:
    ax.bar_label(bars)

# %%
sns.set(rc={'figure.figsize':(27,7)})
sales_state_Product_Category= df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending= False)
ax = sns.barplot(x= 'Product_Category', y= 'Amount', data = sales_state_Product_Category)
for i in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %% [markdown]
# ### Product

# %%
sns.set(rc={'figure.figsize':(27,7)})
sales_state_Product= df.groupby(['Product_ID'],as_index=False)['Amount'].sum().sort_values(by = 'Amount',ascending= False).head(10)
ax = sns.barplot(x= 'Product_ID', y= 'Amount', data = sales_state_Product)
for i in ax.containers:
    ax.bar_label(bars)

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# * Thank You

# %%
# Out:
# array([[<Axes: title={'center': 'User_ID'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'shadhi'}>,
#         <Axes: title={'center': 'Orders'}>],
#        [<Axes: title={'center': 'Amount'}>, <Axes: >]], dtype=object)
